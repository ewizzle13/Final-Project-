# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, f1_score, recall_score

# %%
import os

print("Current folder:", os.getcwd())
print("Files here:", os.listdir())
# Out:
# Current folder: /Users/niurikagonzalez/Desktop/Machine Learning Project/Final-Project-/notebooks/results
# Files here: ['perceptron.ipynb', 'plots']

# %%
data_dir = "../../data/final_project_data_sp2026_L"

csv_files = [
    os.path.join(data_dir, "ids_0.csv"),
    os.path.join(data_dir, "ids_1.csv"),
    os.path.join(data_dir, "ids_2.csv"),
    os.path.join(data_dir, "ids_4_.csv"),
]

parquet_files = [
    os.path.join(data_dir, "ids_5.parquet"),
    os.path.join(data_dir, "ids_6.parquet"),
    os.path.join(data_dir, "ids_8.parquet"),
    os.path.join(data_dir, "ids_11.parquet"),
]

dfs = []

for f in csv_files:
    temp = pd.read_csv(f)
    temp.columns = temp.columns.str.strip()
    dfs.append(temp)

for f in parquet_files:
    temp = pd.read_parquet(f)
    temp.columns = temp.columns.str.strip()
    dfs.append(temp)

df = pd.concat(dfs, ignore_index=True, sort=False)

print(df["Label"].value_counts())
print(df["Label"].unique())
# Out:
# Label
# DoS Hulk         21027
# DoS GoldenEye    10293
# BENIGN            4004
# Name: count, dtype: int64
# ['BENIGN' 'DoS Hulk' 'DoS GoldenEye']

# %%
display(df)
# Out:
#        Destination Port  Flow Duration  Total Fwd Packets  \
# 0                    53          61205                  4
# 1                    53            222                  2
# 2                    53          23759                  2
# 3                    80            401                  2
# 4                 57406              4                  2
# ...                 ...            ...                ...
# 35319                80      101304725                  7
# 35320                80         144456                  3
# 35321                80       99934662                  5
# 35322                80       86074100                  6
# 35323                80       98494641                  6
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# 0                           2                          136
# 1                           2                           90
# 2                           2                           70
# 3                           0                           12
# 4                           0                           12
# ...                       ...                          ...
# 35319                       6                         1110
# 35320                       6                          333
# 35321                       7                          315
# 35322                       8                          431
# 35323                       6                          310
#
#        Total Length of Bwd Packets  Fwd Packet Length Max  \
# 0                              428                     34
# 1                              172                     45
# 2                              126                     35
# 3                                0                      6
# 4                                0                      6
# ...                            ...                    ...
# 35319                        11595                    366
# 35320                        11595                    333
# 35321                        11595                    303
# 35322                        11595                    413
# 35323                        11595                    310
#
#        Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std  \
# 0                         34               34.000000               0.000000
# 1                         45               45.000000               0.000000
# 2                         35               35.000000               0.000000
# 3                          6                6.000000               0.000000
# 4                          6                6.000000               0.000000
# ...                      ...                     ...                    ...
# 35319                      0              158.571429             194.047122
# 35320                      0              111.000000             192.257640
# 35321                      0               63.000000             134.197616
# 35322                      0               71.833333             167.162695
# 35323                      0               51.666667             126.556970
#
#        ...  min_seg_size_forward  Active Mean  Active Std  Active Max  \
# 0      ...                    32          0.0         0.0           0
# 1      ...                    20          0.0         0.0           0
# 2      ...                    32          0.0         0.0           0
# 3      ...                    20          0.0         0.0           0
# 4      ...                    20          0.0         0.0           0
# ...    ...                   ...          ...         ...         ...
# 35319  ...                    20       3986.0         0.0        3986
# 35320  ...                    32          0.0         0.0           0
# 35321  ...                    20      10008.0         0.0       10008
# 35322  ...                    20      11997.0         0.0       11997
# 35323  ...                    32          5.0         0.0           5
#
#        Active Min    Idle Mean  Idle Std   Idle Max   Idle Min     Label
# 0               0          0.0       0.0          0          0    BENIGN
# 1               0          0.0       0.0          0          0    BENIGN
# 2               0          0.0       0.0          0          0    BENIGN
# 3               0          0.0       0.0          0          0    BENIGN
# 4               0          0.0       0.0          0          0    BENIGN
# ...           ...          ...       ...        ...        ...       ...
# 35319        3986  101000000.0       0.0  101000000  101000000  DoS Hulk
# 35320           0          0.0       0.0          0          0  DoS Hulk
# 35321       10008   99900000.0       0.0   99900000   99900000  DoS Hulk
# 35322       11997   85900000.0       0.0   85900000   85900000  DoS Hulk
# 35323           5   98500000.0       0.0   98500000   98500000  DoS Hulk
#
# [35324 rows x 79 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35324 entries, 0 to 35323
# Data columns (total 79 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Destination Port             35324 non-null  int64
#  1   Flow Duration                35324 non-null  int64
#  2   Total Fwd Packets            35324 non-null  int64
#  3   Total Backward Packets       35324 non-null  int64
#  4   Total Length of Fwd Packets  35324 non-null  int64
#  5   Total Length of Bwd Packets  35324 non-null  int64
#  6   Fwd Packet Length Max        35324 non-null  int64
#  7   Fwd Packet Length Min        35324 non-null  int64
#  8   Fwd Packet Length Mean       35324 non-null  float64
#  9   Fwd Packet Length Std        35324 non-null  float64
#  10  Bwd Packet Length Max        35324 non-null  int64
#  11  Bwd Packet Length Min        35324 non-null  int64
#  12  Bwd Packet Length Mean       35324 non-null  float64
#  13  Bwd Packet Length Std        35324 non-null  float64
#  14  Flow Bytes/s                 35239 non-null  float64
#  15  Flow Packets/s               35324 non-null  float64
#  16  Flow IAT Mean                35324 non-null  float64
#  17  Flow IAT Std                 35324 non-null  float64
#  18  Flow IAT Max                 35324 non-null  int64
#  19  Flow IAT Min                 35324 non-null  int64
#  20  Fwd IAT Total                35324 non-null  int64
#  21  Fwd IAT Mean                 35324 non-null  float64
#  22  Fwd IAT Std                  35324 non-null  float64
#  23  Fwd IAT Max                  35324 non-null  int64
#  24  Fwd IAT Min                  35324 non-null  int64
#  25  Bwd IAT Total                35324 non-null  int64
#  26  Bwd IAT Mean                 35324 non-null  float64
#  27  Bwd IAT Std                  35324 non-null  float64
#  28  Bwd IAT Max                  35324 non-null  int64
#  29  Bwd IAT Min                  35324 non-null  int64
#  30  Fwd PSH Flags                35324 non-null  int64
#  31  Bwd PSH Flags                35324 non-null  int64
#  32  Fwd URG Flags                35324 non-null  int64
#  33  Bwd URG Flags                35324 non-null  int64
#  34  Fwd Header Length            35324 non-null  int64
#  35  Bwd Header Length            35324 non-null  int64
#  36  Fwd Packets/s                35324 non-null  float64
#  37  Bwd Packets/s                35324 non-null  float64
#  38  Min Packet Length            35324 non-null  int64
#  39  Max Packet Length            35324 non-null  int64
#  40  Packet Length Mean           35324 non-null  float64
#  41  Packet Length Std            35324 non-null  float64
#  42  Packet Length Variance       35324 non-null  float64
#  43  FIN Flag Count               35324 non-null  int64
#  44  SYN Flag Count               35324 non-null  int64
#  45  RST Flag Count               35324 non-null  int64
#  46  PSH Flag Count               35324 non-null  int64
#  47  ACK Flag Count               35324 non-null  int64
#  48  URG Flag Count               35324 non-null  int64
#  49  CWE Flag Count               35324 non-null  int64
#  50  ECE Flag Count               35324 non-null  int64
#  51  Down/Up Ratio                35324 non-null  int64
#  52  Average Packet Size          35324 non-null  float64
#  53  Avg Fwd Segment Size         35324 non-null  float64
#  54  Avg Bwd Segment Size         35324 non-null  float64
#  55  Fwd Header Length.1          35324 non-null  int64
#  56  Fwd Avg Bytes/Bulk           35324 non-null  int64
#  57  Fwd Avg Packets/Bulk         35324 non-null  int64
#  58  Fwd Avg Bulk Rate            35324 non-null  int64
#  59  Bwd Avg Bytes/Bulk           35324 non-null  int64
#  60  Bwd Avg Packets/Bulk         35324 non-null  int64
#  61  Bwd Avg Bulk Rate            35324 non-null  int64
#  62  Subflow Fwd Packets          35324 non-null  int64
#  63  Subflow Fwd Bytes            35324 non-null  int64
#  64  Subflow Bwd Packets          35324 non-null  int64
#  65  Subflow Bwd Bytes            35324 non-null  int64
#  66  Init_Win_bytes_forward       35324 non-null  int64
#  67  Init_Win_bytes_backward      35324 non-null  int64
#  68  act_data_pkt_fwd             35324 non-null  int64
#  69  min_seg_size_forward         35324 non-null  int64
#  70  Active Mean                  35324 non-null  float64
#  71  Active Std                   35324 non-null  float64
#  72  Active Max                   35324 non-null  int64
#  73  Active Min                   35324 non-null  int64
#  74  Idle Mean                    35324 non-null  float64
#  75  Idle Std                     35324 non-null  float64
#  76  Idle Max                     35324 non-null  int64
#  77  Idle Min                     35324 non-null  int64
#  78  Label                        35324 non-null  object
# dtypes: float64(24), int64(54), object(1)
# memory usage: 21.3+ MB
#        Destination Port  Flow Duration  Total Fwd Packets  \
# count      35324.000000   3.532400e+04       35324.000000
# mean        1203.752548   4.217434e+07           6.762569
# std         7437.161180   4.399691e+07         139.226812
# min            0.000000   0.000000e+00           1.000000
# 25%           80.000000   2.862825e+04           2.000000
# 50%           80.000000   1.185260e+07           6.000000
# 75%           80.000000   8.678486e+07           8.000000
# max        64249.000000   1.199997e+08       18649.000000
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# count            35324.000000                 35324.000000
# mean                 5.931435                   399.455951
# std                189.397082                  2893.066268
# min                  0.000000                     0.000000
# 25%                  0.000000                     0.000000
# 50%                  5.000000                   337.000000
# 75%                  6.000000                   387.000000
# max              25335.000000                312775.000000
#
#        Total Length of Bwd Packets  Fwd Packet Length Max  \
# count                 3.532400e+04           35324.000000
# mean                  1.075409e+04             258.691824
# std                   4.242184e+05             317.537827
# min                   0.000000e+00               0.000000
# 25%                   0.000000e+00               0.000000
# 50%                   1.159500e+04             326.000000
# 75%                   1.159500e+04             370.000000
# max                   5.610000e+07           11595.000000
#
#        Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std  \
# count           35324.000000            35324.000000           35324.000000
# mean                2.535557               52.029713             104.236133
# std                16.209431               81.108565             126.229514
# min                 0.000000                0.000000               0.000000
# 25%                 0.000000                0.000000               0.000000
# 50%                 0.000000               47.000000             124.450794
# 75%                 0.000000               65.600000             153.870725
# max              1399.000000             2319.000000            5185.441640
#
#        ...  act_data_pkt_fwd  min_seg_size_forward   Active Mean  \
# count  ...      35324.000000          35324.000000  3.532400e+04
# mean   ...          2.632969             28.664930  7.052138e+04
# std    ...        137.232841              5.433104  5.222983e+05
# min    ...          0.000000              0.000000  0.000000e+00
# 25%    ...          0.000000             20.000000  0.000000e+00
# 50%    ...          1.000000             32.000000  5.000000e+00
# 75%    ...          2.000000             32.000000  1.070000e+03
# max    ...      18392.000000             56.000000  1.370000e+07
#
#          Active Std    Active Max    Active Min     Idle Mean      Idle Std  \
# count  3.532400e+04  3.532400e+04  3.532400e+04  3.532400e+04  3.532400e+04
# mean   1.419158e+04  8.791439e+04  6.153310e+04  3.931697e+07  5.538478e+05
# std    2.319484e+05  6.436837e+05  4.897209e+05  4.390458e+07  5.575378e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  5.000000e+00  5.000000e+00  6.839338e+06  0.000000e+00
# 75%    0.000000e+00  1.070000e+03  1.057000e+03  8.550000e+07  0.000000e+00
# max    1.180000e+07  2.410000e+07  1.370000e+07  1.200000e+08  6.070000e+07
#
#            Idle Max      Idle Min
# count  3.532400e+04  3.532400e+04
# mean   3.971454e+07  3.891569e+07
# std    4.422689e+07  4.394162e+07
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    6.839338e+06  6.801360e+06
# 75%    8.570000e+07  8.550000e+07
# max    1.200000e+08  1.200000e+08
#
# [8 rows x 78 columns]

# %%
def transform_data(df):
    df = df.drop_duplicates().copy()
    df["Label"] = df["Label"].str.strip()

    # remove Heartbleed
    df = df[df["Label"] != "Heartbleed"].copy()

    # binary labels
    df["Label"] = df["Label"].apply(
        lambda x: "benign" if x.lower() == "benign" else "attack"
    )

    print("\nBinary labels:")
    print(df["Label"].value_counts())

    X = df.drop(columns=["Label"])
    y = df["Label"]

    return X, y, df
def remove_outliers_iqr(df):
    df = df.copy()

    numeric_cols = df.select_dtypes(include=[np.number]).columns

    # calculate IQR correctly
    Q1 = df[numeric_cols].quantile(0.25)
    Q3 = df[numeric_cols].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    for col in numeric_cols:
        median = df[col].median()
        df[col] = np.where(
            (df[col] < lower_bound[col]) | (df[col] > upper_bound[col]),
            median,
            df[col]
        )

    return df
x, y, df_clean = transform_data(df)

print(x.shape)
print(y.shape)
# Out:
# Binary labels:
# Label
# attack    25630
# benign     2971
# Name: count, dtype: int64
# (28601, 78)
# (28601,)

# %%
numeric_cols = x.select_dtypes(include=[np.number])

plt.figure(figsize=(20, 6))
numeric_cols.iloc[:, :10].boxplot()
plt.xticks(rotation=45)
plt.title("Boxplots of First 10 Numeric Features")
plt.show()

# %%
dataset = df.copy(deep=True)

# %%
# display the first rows of the dataframe dataset
dataset.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0                53          61205                  4                       2
# 1                53            222                  2                       2
# 2                53          23759                  2                       2
# 3                80            401                  2                       0
# 4             57406              4                  2                       0
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                          136                          428
# 1                           90                          172
# 2                           70                          126
# 3                           12                            0
# 4                           12                            0
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                     34                     34                    34.0
# 1                     45                     45                    45.0
# 2                     35                     35                    35.0
# 3                      6                      6                     6.0
# 4                      6                      6                     6.0
#
#    Fwd Packet Length Std  ...  min_seg_size_forward  Active Mean  Active Std  \
# 0                    0.0  ...                    32          0.0         0.0
# 1                    0.0  ...                    20          0.0         0.0
# 2                    0.0  ...                    32          0.0         0.0
# 3                    0.0  ...                    20          0.0         0.0
# 4                    0.0  ...                    20          0.0         0.0
#
#    Active Max  Active Min  Idle Mean  Idle Std  Idle Max  Idle Min   Label
# 0           0           0        0.0       0.0         0         0  BENIGN
# 1           0           0        0.0       0.0         0         0  BENIGN
# 2           0           0        0.0       0.0         0         0  BENIGN
# 3           0           0        0.0       0.0         0         0  BENIGN
# 4           0           0        0.0       0.0         0         0  BENIGN
#
# [5 rows x 79 columns]

# %%
# let's check if the data is standardized (mean=0, std=1)
# This should be performed when we convert the dataframe into a numpy array for classification
dataset.describe()
# Out:
#        Destination Port  Flow Duration  Total Fwd Packets  \
# count      35324.000000   3.532400e+04       35324.000000
# mean        1203.752548   4.217434e+07           6.762569
# std         7437.161180   4.399691e+07         139.226812
# min            0.000000   0.000000e+00           1.000000
# 25%           80.000000   2.862825e+04           2.000000
# 50%           80.000000   1.185260e+07           6.000000
# 75%           80.000000   8.678486e+07           8.000000
# max        64249.000000   1.199997e+08       18649.000000
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# count            35324.000000                 35324.000000
# mean                 5.931435                   399.455951
# std                189.397082                  2893.066268
# min                  0.000000                     0.000000
# 25%                  0.000000                     0.000000
# 50%                  5.000000                   337.000000
# 75%                  6.000000                   387.000000
# max              25335.000000                312775.000000
#
#        Total Length of Bwd Packets  Fwd Packet Length Max  \
# count                 3.532400e+04           35324.000000
# mean                  1.075409e+04             258.691824
# std                   4.242184e+05             317.537827
# min                   0.000000e+00               0.000000
# 25%                   0.000000e+00               0.000000
# 50%                   1.159500e+04             326.000000
# 75%                   1.159500e+04             370.000000
# max                   5.610000e+07           11595.000000
#
#        Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std  \
# count           35324.000000            35324.000000           35324.000000
# mean                2.535557               52.029713             104.236133
# std                16.209431               81.108565             126.229514
# min                 0.000000                0.000000               0.000000
# 25%                 0.000000                0.000000               0.000000
# 50%                 0.000000               47.000000             124.450794
# 75%                 0.000000               65.600000             153.870725
# max              1399.000000             2319.000000            5185.441640
#
#        ...  act_data_pkt_fwd  min_seg_size_forward   Active Mean  \
# count  ...      35324.000000          35324.000000  3.532400e+04
# mean   ...          2.632969             28.664930  7.052138e+04
# std    ...        137.232841              5.433104  5.222983e+05
# min    ...          0.000000              0.000000  0.000000e+00
# 25%    ...          0.000000             20.000000  0.000000e+00
# 50%    ...          1.000000             32.000000  5.000000e+00
# 75%    ...          2.000000             32.000000  1.070000e+03
# max    ...      18392.000000             56.000000  1.370000e+07
#
#          Active Std    Active Max    Active Min     Idle Mean      Idle Std  \
# count  3.532400e+04  3.532400e+04  3.532400e+04  3.532400e+04  3.532400e+04
# mean   1.419158e+04  8.791439e+04  6.153310e+04  3.931697e+07  5.538478e+05
# std    2.319484e+05  6.436837e+05  4.897209e+05  4.390458e+07  5.575378e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  5.000000e+00  5.000000e+00  6.839338e+06  0.000000e+00
# 75%    0.000000e+00  1.070000e+03  1.057000e+03  8.550000e+07  0.000000e+00
# max    1.180000e+07  2.410000e+07  1.370000e+07  1.200000e+08  6.070000e+07
#
#            Idle Max      Idle Min
# count  3.532400e+04  3.532400e+04
# mean   3.971454e+07  3.891569e+07
# std    4.422689e+07  4.394162e+07
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    6.839338e+06  6.801360e+06
# 75%    8.570000e+07  8.550000e+07
# max    1.200000e+08  1.200000e+08
#
# [8 rows x 78 columns]

# %%
# display the information of the dataset dataframe
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35324 entries, 0 to 35323
# Data columns (total 79 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Destination Port             35324 non-null  int64
#  1   Flow Duration                35324 non-null  int64
#  2   Total Fwd Packets            35324 non-null  int64
#  3   Total Backward Packets       35324 non-null  int64
#  4   Total Length of Fwd Packets  35324 non-null  int64
#  5   Total Length of Bwd Packets  35324 non-null  int64
#  6   Fwd Packet Length Max        35324 non-null  int64
#  7   Fwd Packet Length Min        35324 non-null  int64
#  8   Fwd Packet Length Mean       35324 non-null  float64
#  9   Fwd Packet Length Std        35324 non-null  float64
#  10  Bwd Packet Length Max        35324 non-null  int64
#  11  Bwd Packet Length Min        35324 non-null  int64
#  12  Bwd Packet Length Mean       35324 non-null  float64
#  13  Bwd Packet Length Std        35324 non-null  float64
#  14  Flow Bytes/s                 35239 non-null  float64
#  15  Flow Packets/s               35324 non-null  float64
#  16  Flow IAT Mean                35324 non-null  float64
#  17  Flow IAT Std                 35324 non-null  float64
#  18  Flow IAT Max                 35324 non-null  int64
#  19  Flow IAT Min                 35324 non-null  int64
#  20  Fwd IAT Total                35324 non-null  int64
#  21  Fwd IAT Mean                 35324 non-null  float64
#  22  Fwd IAT Std                  35324 non-null  float64
#  23  Fwd IAT Max                  35324 non-null  int64
#  24  Fwd IAT Min                  35324 non-null  int64
#  25  Bwd IAT Total                35324 non-null  int64
#  26  Bwd IAT Mean                 35324 non-null  float64
#  27  Bwd IAT Std                  35324 non-null  float64
#  28  Bwd IAT Max                  35324 non-null  int64
#  29  Bwd IAT Min                  35324 non-null  int64
#  30  Fwd PSH Flags                35324 non-null  int64
#  31  Bwd PSH Flags                35324 non-null  int64
#  32  Fwd URG Flags                35324 non-null  int64
#  33  Bwd URG Flags                35324 non-null  int64
#  34  Fwd Header Length            35324 non-null  int64
#  35  Bwd Header Length            35324 non-null  int64
#  36  Fwd Packets/s                35324 non-null  float64
#  37  Bwd Packets/s                35324 non-null  float64
#  38  Min Packet Length            35324 non-null  int64
#  39  Max Packet Length            35324 non-null  int64
#  40  Packet Length Mean           35324 non-null  float64
#  41  Packet Length Std            35324 non-null  float64
#  42  Packet Length Variance       35324 non-null  float64
#  43  FIN Flag Count               35324 non-null  int64
#  44  SYN Flag Count               35324 non-null  int64
#  45  RST Flag Count               35324 non-null  int64
#  46  PSH Flag Count               35324 non-null  int64
#  47  ACK Flag Count               35324 non-null  int64
#  48  URG Flag Count               35324 non-null  int64
#  49  CWE Flag Count               35324 non-null  int64
#  50  ECE Flag Count               35324 non-null  int64
#  51  Down/Up Ratio                35324 non-null  int64
#  52  Average Packet Size          35324 non-null  float64
#  53  Avg Fwd Segment Size         35324 non-null  float64
#  54  Avg Bwd Segment Size         35324 non-null  float64
#  55  Fwd Header Length.1          35324 non-null  int64
#  56  Fwd Avg Bytes/Bulk           35324 non-null  int64
#  57  Fwd Avg Packets/Bulk         35324 non-null  int64
#  58  Fwd Avg Bulk Rate            35324 non-null  int64
#  59  Bwd Avg Bytes/Bulk           35324 non-null  int64
#  60  Bwd Avg Packets/Bulk         35324 non-null  int64
#  61  Bwd Avg Bulk Rate            35324 non-null  int64
#  62  Subflow Fwd Packets          35324 non-null  int64
#  63  Subflow Fwd Bytes            35324 non-null  int64
#  64  Subflow Bwd Packets          35324 non-null  int64
#  65  Subflow Bwd Bytes            35324 non-null  int64
#  66  Init_Win_bytes_forward       35324 non-null  int64
#  67  Init_Win_bytes_backward      35324 non-null  int64
#  68  act_data_pkt_fwd             35324 non-null  int64
#  69  min_seg_size_forward         35324 non-null  int64
#  70  Active Mean                  35324 non-null  float64
#  71  Active Std                   35324 non-null  float64
#  72  Active Max                   35324 non-null  int64
#  73  Active Min                   35324 non-null  int64
#  74  Idle Mean                    35324 non-null  float64
#  75  Idle Std                     35324 non-null  float64
#  76  Idle Max                     35324 non-null  int64
#  77  Idle Min                     35324 non-null  int64
#  78  Label                        35324 non-null  object
# dtypes: float64(24), int64(54), object(1)
# memory usage: 21.3+ MB

# %%
# display the list of labels
dataset["Label"].value_counts()
# Out:
# Label
# DoS Hulk         21027
# DoS GoldenEye    10293
# BENIGN            4004
# Name: count, dtype: int64

# %%
# Create the binary target:
#  1  = DoS Hulk
# -1  = all other attacks / classes
target_dos_hulk = dataset["Label"].apply(
    lambda x: 1 if str(x).strip() == "DoS Hulk" else -1
)

target_dos_hulk.value_counts()
# Out:
# Label
#  1    21027
# -1    14297
# Name: count, dtype: int64

# %%
# Separate features and target
# IMPORTANT: drop Label so it does not end up inside X
X = dataset.drop(columns=["Label"]).copy()
y = target_dos_hulk.copy()

print(X.shape, y.shape)
# Out:
# (35324, 78) (35324,)

# %%
# Make sure all feature columns are numeric
X = X.apply(pd.to_numeric, errors="coerce")

# Fill any missing values created during conversion
X = X.fillna(0)

X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35324 entries, 0 to 35323
# Data columns (total 78 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Destination Port             35324 non-null  int64
#  1   Flow Duration                35324 non-null  int64
#  2   Total Fwd Packets            35324 non-null  int64
#  3   Total Backward Packets       35324 non-null  int64
#  4   Total Length of Fwd Packets  35324 non-null  int64
#  5   Total Length of Bwd Packets  35324 non-null  int64
#  6   Fwd Packet Length Max        35324 non-null  int64
#  7   Fwd Packet Length Min        35324 non-null  int64
#  8   Fwd Packet Length Mean       35324 non-null  float64
#  9   Fwd Packet Length Std        35324 non-null  float64
#  10  Bwd Packet Length Max        35324 non-null  int64
#  11  Bwd Packet Length Min        35324 non-null  int64
#  12  Bwd Packet Length Mean       35324 non-null  float64
#  13  Bwd Packet Length Std        35324 non-null  float64
#  14  Flow Bytes/s                 35324 non-null  float64
#  15  Flow Packets/s               35324 non-null  float64
#  16  Flow IAT Mean                35324 non-null  float64
#  17  Flow IAT Std                 35324 non-null  float64
#  18  Flow IAT Max                 35324 non-null  int64
#  19  Flow IAT Min                 35324 non-null  int64
#  20  Fwd IAT Total                35324 non-null  int64
#  21  Fwd IAT Mean                 35324 non-null  float64
#  22  Fwd IAT Std                  35324 non-null  float64
#  23  Fwd IAT Max                  35324 non-null  int64
#  24  Fwd IAT Min                  35324 non-null  int64
#  25  Bwd IAT Total                35324 non-null  int64
#  26  Bwd IAT Mean                 35324 non-null  float64
#  27  Bwd IAT Std                  35324 non-null  float64
#  28  Bwd IAT Max                  35324 non-null  int64
#  29  Bwd IAT Min                  35324 non-null  int64
#  30  Fwd PSH Flags                35324 non-null  int64
#  31  Bwd PSH Flags                35324 non-null  int64
#  32  Fwd URG Flags                35324 non-null  int64
#  33  Bwd URG Flags                35324 non-null  int64
#  34  Fwd Header Length            35324 non-null  int64
#  35  Bwd Header Length            35324 non-null  int64
#  36  Fwd Packets/s                35324 non-null  float64
#  37  Bwd Packets/s                35324 non-null  float64
#  38  Min Packet Length            35324 non-null  int64
#  39  Max Packet Length            35324 non-null  int64
#  40  Packet Length Mean           35324 non-null  float64
#  41  Packet Length Std            35324 non-null  float64
#  42  Packet Length Variance       35324 non-null  float64
#  43  FIN Flag Count               35324 non-null  int64
#  44  SYN Flag Count               35324 non-null  int64
#  45  RST Flag Count               35324 non-null  int64
#  46  PSH Flag Count               35324 non-null  int64
#  47  ACK Flag Count               35324 non-null  int64
#  48  URG Flag Count               35324 non-null  int64
#  49  CWE Flag Count               35324 non-null  int64
#  50  ECE Flag Count               35324 non-null  int64
#  51  Down/Up Ratio                35324 non-null  int64
#  52  Average Packet Size          35324 non-null  float64
#  53  Avg Fwd Segment Size         35324 non-null  float64
#  54  Avg Bwd Segment Size         35324 non-null  float64
#  55  Fwd Header Length.1          35324 non-null  int64
#  56  Fwd Avg Bytes/Bulk           35324 non-null  int64
#  57  Fwd Avg Packets/Bulk         35324 non-null  int64
#  58  Fwd Avg Bulk Rate            35324 non-null  int64
#  59  Bwd Avg Bytes/Bulk           35324 non-null  int64
#  60  Bwd Avg Packets/Bulk         35324 non-null  int64
#  61  Bwd Avg Bulk Rate            35324 non-null  int64
#  62  Subflow Fwd Packets          35324 non-null  int64
#  63  Subflow Fwd Bytes            35324 non-null  int64
#  64  Subflow Bwd Packets          35324 non-null  int64
#  65  Subflow Bwd Bytes            35324 non-null  int64
#  66  Init_Win_bytes_forward       35324 non-null  int64
#  67  Init_Win_bytes_backward      35324 non-null  int64
#  68  act_data_pkt_fwd             35324 non-null  int64
#  69  min_seg_size_forward         35324 non-null  int64
#  70  Active Mean                  35324 non-null  float64
#  71  Active Std                   35324 non-null  float64
#  72  Active Max                   35324 non-null  int64
#  73  Active Min                   35324 non-null  int64
#  74  Idle Mean                    35324 non-null  float64
#  75  Idle Std                     35324 non-null  float64
#  76  Idle Max                     35324 non-null  int64
#  77  Idle Min                     35324 non-null  int64
# dtypes: float64(24), int64(54)
# memory usage: 21.0 MB

# %%
# Check whether any non-numeric columns remain
print(X.select_dtypes(include="object").columns.tolist())
# Out:
# []

# %%
# Convert to numpy arrays
X = X.to_numpy()
y = y.to_numpy().flatten()

print(X.shape, y.shape)
# Out:
# (35324, 78) (35324,)

# %%
y[:10]
X[:5]
# Out:
# array([[ 5.30000000e+01,  6.12050000e+04,  4.00000000e+00,
#          2.00000000e+00,  1.36000000e+02,  4.28000000e+02,
#          3.40000000e+01,  3.40000000e+01,  3.40000000e+01,
#          0.00000000e+00,  2.14000000e+02,  2.14000000e+02,
#          2.14000000e+02,  0.00000000e+00,  9.21493342e+03,
#          9.80312066e+01,  1.22410000e+04,  1.68671714e+04,
#          3.33180000e+04,  3.00000000e+00,  3.33240000e+04,
#          1.11080000e+04,  1.92344242e+04,  3.33180000e+04,
#          3.00000000e+00,  4.00000000e+00,  4.00000000e+00,
#          0.00000000e+00,  4.00000000e+00,  4.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.28000000e+02,  4.00000000e+01,
#          6.53541377e+01,  3.26770689e+01,  3.40000000e+01,
#          2.14000000e+02,  8.54285714e+01,  8.78310066e+01,
#          7.71428571e+03,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  9.96666667e+01,  3.40000000e+01,
#          2.14000000e+02,  1.28000000e+02,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  4.00000000e+00,
#          1.36000000e+02,  2.00000000e+00,  4.28000000e+02,
#         -1.00000000e+00, -1.00000000e+00,  3.00000000e+00,
#          3.20000000e+01,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 5.30000000e+01,  2.22000000e+02,  2.00000000e+00,
#          2.00000000e+00,  9.00000000e+01,  1.72000000e+02,
#          4.50000000e+01,  4.50000000e+01,  4.50000000e+01,
#          0.00000000e+00,  8.60000000e+01,  8.60000000e+01,
#          8.60000000e+01,  0.00000000e+00,  1.18018018e+06,
#          1.80180180e+04,  7.40000000e+01,  8.60000000e+01,
#          1.70000000e+02,  4.00000000e+00,  4.80000000e+01,
#          4.80000000e+01,  0.00000000e+00,  4.80000000e+01,
#          4.80000000e+01,  4.00000000e+00,  4.00000000e+00,
#          0.00000000e+00,  4.00000000e+00,  4.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  4.00000000e+01,  4.00000000e+01,
#          9.00900901e+03,  9.00900901e+03,  4.50000000e+01,
#          8.60000000e+01,  6.14000000e+01,  2.24566249e+01,
#          5.04300000e+02,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  7.67500000e+01,  4.50000000e+01,
#          8.60000000e+01,  4.00000000e+01,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  2.00000000e+00,
#          9.00000000e+01,  2.00000000e+00,  1.72000000e+02,
#         -1.00000000e+00, -1.00000000e+00,  1.00000000e+00,
#          2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 5.30000000e+01,  2.37590000e+04,  2.00000000e+00,
#          2.00000000e+00,  7.00000000e+01,  1.26000000e+02,
#          3.50000000e+01,  3.50000000e+01,  3.50000000e+01,
#          0.00000000e+00,  6.30000000e+01,  6.30000000e+01,
#          6.30000000e+01,  0.00000000e+00,  8.24950545e+03,
#          1.68357254e+02,  7.91966667e+03,  1.37112029e+04,
#          2.37520000e+04,  3.00000000e+00,  4.00000000e+00,
#          4.00000000e+00,  0.00000000e+00,  4.00000000e+00,
#          4.00000000e+00,  3.00000000e+00,  3.00000000e+00,
#          0.00000000e+00,  3.00000000e+00,  3.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  6.40000000e+01,  4.00000000e+01,
#          8.41786271e+01,  8.41786271e+01,  3.50000000e+01,
#          6.30000000e+01,  4.62000000e+01,  1.53362316e+01,
#          2.35200000e+02,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  5.77500000e+01,  3.50000000e+01,
#          6.30000000e+01,  6.40000000e+01,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  2.00000000e+00,
#          7.00000000e+01,  2.00000000e+00,  1.26000000e+02,
#         -1.00000000e+00, -1.00000000e+00,  1.00000000e+00,
#          3.20000000e+01,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 8.00000000e+01,  4.01000000e+02,  2.00000000e+00,
#          0.00000000e+00,  1.20000000e+01,  0.00000000e+00,
#          6.00000000e+00,  6.00000000e+00,  6.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  2.99251870e+04,
#          4.98753117e+03,  4.01000000e+02,  0.00000000e+00,
#          4.01000000e+02,  4.01000000e+02,  4.01000000e+02,
#          4.01000000e+02,  0.00000000e+00,  4.01000000e+02,
#          4.01000000e+02,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  4.00000000e+01,  0.00000000e+00,
#          4.98753117e+03,  0.00000000e+00,  6.00000000e+00,
#          6.00000000e+00,  6.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  9.00000000e+00,  6.00000000e+00,
#          0.00000000e+00,  4.00000000e+01,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  2.00000000e+00,
#          1.20000000e+01,  0.00000000e+00,  0.00000000e+00,
#          2.53000000e+02, -1.00000000e+00,  1.00000000e+00,
#          2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 5.74060000e+04,  4.00000000e+00,  2.00000000e+00,
#          0.00000000e+00,  1.20000000e+01,  0.00000000e+00,
#          6.00000000e+00,  6.00000000e+00,  6.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+06,
#          5.00000000e+05,  4.00000000e+00,  0.00000000e+00,
#          4.00000000e+00,  4.00000000e+00,  4.00000000e+00,
#          4.00000000e+00,  0.00000000e+00,  4.00000000e+00,
#          4.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  4.00000000e+01,  0.00000000e+00,
#          5.00000000e+05,  0.00000000e+00,  6.00000000e+00,
#          6.00000000e+00,  6.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  9.00000000e+00,  6.00000000e+00,
#          0.00000000e+00,  4.00000000e+01,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  2.00000000e+00,
#          1.20000000e+01,  0.00000000e+00,  0.00000000e+00,
#          3.62000000e+02, -1.00000000e+00,  1.00000000e+00,
#          2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]])

# %%
# Verify the target classes
np.unique(y, return_counts=True)
# Out:
# (array([-1,  1]), array([14297, 21027]))

# %%
# Split the dataset into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=1,
    stratify=y
)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (26493, 78) (8831, 78) (26493,) (8831,)

# %%
# Create the Perceptron model
from sklearn.linear_model import Perceptron

perceptron = Perceptron(
    eta0=0.001,
    random_state=1
)

# %%
# train the model using the training dataset
#normalize the data before training the model
scaler = StandardScaler()

# replace infinite or non-finite values before scaling
X_train = np.nan_to_num(X_train, nan=0.0, posinf=0.0, neginf=0.0)
X_test = np.nan_to_num(X_test, nan=0.0, posinf=0.0, neginf=0.0)

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

perceptron.fit(X_train, y_train)
X_test = scaler.transform(X_test)

perceptron.fit(X_train, y_train)
# Out:
# Perceptron(eta0=0.001, random_state=1)

# %%
# Predict the labels for the test dataset
pred = perceptron.predict(X_test)

# %%
# Make sure to use the numpy array X_test, not the pandas DataFrame
pred = perceptron.predict(X_test)

acc_perc = accuracy_score(y_test, pred)
f1score_perc = f1_score(y_test, pred)
precision_perc = precision_score(y_test, pred)
recall_perc = recall_score(y_test, pred)

print('Perceptron Model')
print('-'*20)
print('Accuracy: {:.3f}'.format(acc_perc))
print('Precision: {:.3f}'.format(precision_perc))
print('Recall: {:.3f}'.format(recall_perc))
print('F1-score: {:.3f}'.format(f1score_perc))
# Out:
# Perceptron Model
# --------------------
# Accuracy: 0.639
# Precision: 0.629
# Recall: 0.956
# F1-score: 0.759

# %%
# display the confusion matrix
# Both the in-sample and out-of-sample data are used
from sklearn.metrics import ConfusionMatrixDisplay


ConfusionMatrixDisplay.from_estimator(perceptron, np.concatenate((X_train, X_test), axis=0), 
                                      np.concatenate((y_train, y_test)))
